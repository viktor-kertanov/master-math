# %% [markdown]
# # COURSE: Master math by coding in Python
# ## SECTION: Number theory BUG HUNT!
#
# #### https://www.udemy.com/course/math-with-python/?couponCode=MXC-DISC4ALL
# #### INSTRUCTOR: sincxpress.com

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Math
import sympy as sym

# %% [markdown]
# Find integer solutions to $x^1+y^2=z^3$

# %%
ints = np.arange(1, 101)
z = np.zeros((len(ints),len(ints)))

 

# run the simulation
for x_idx, x in enumerate(ints):
    for y_idx, y in enumerate(ints):
        z[x_idx, y_idx] = np.cbrt((x + y**2))

# check for integers
zInts = z % 1 == 0

# now visualize
fig, ax = plt.subplots(1 ,2, figsize=(12,6))
fig.tight_layout(pad=5)

# show the resulting z-values
h = ax[0].imshow(z)
fig.colorbar(h, ax=ax[0],fraction=.045)
ax[0].set_xlabel('y')
ax[0].set_ylabel('x')
ax[0].set_title('$z=\sqrt[3]{x^1+y^2}$',fontsize=16)

# show the boolean integer map
h = ax[1].imshow(zInts,vmin=0,vmax=1)
fig.colorbar(h, ax=ax[1], fraction=.045)
ax[1].set_xlabel('y')
ax[1].set_ylabel('x')
ax[1].set_title('Whether $z$ is int',fontsize=16)

plt.show()

# %%
# print out those triplets
# run the simulation
for x in ints:
    for y in ints:
        z = np.cbrt((x + y**2))
        # check for integers
        if z % 1 == 0:
            display(Math('$%i^3 = %i + %i^2 \\qquad \\Rightarrow %i =  %s$' %(z, x, y, z**3, x+y**2)))
# Out:
# $\displaystyle 3^3 = 2 + 5^2 \qquad \Rightarrow 27 =  27$
# $\displaystyle 2^3 = 4 + 2^2 \qquad \Rightarrow 8 =  8$
# $\displaystyle 5^3 = 4 + 11^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 2^3 = 7 + 1^2 \qquad \Rightarrow 8 =  8$
# $\displaystyle 3^3 = 11 + 4^2 \qquad \Rightarrow 27 =  27$
# $\displaystyle 15^3 = 11 + 58^2 \qquad \Rightarrow 3375 =  3375$
# $\displaystyle 17^3 = 13 + 70^2 \qquad \Rightarrow 4913 =  4913$
# $\displaystyle 4^3 = 15 + 7^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 3^3 = 18 + 3^2 \qquad \Rightarrow 27 =  27$
# $\displaystyle 7^3 = 19 + 18^2 \qquad \Rightarrow 343 =  343$
# $\displaystyle 6^3 = 20 + 14^2 \qquad \Rightarrow 216 =  216$
# $\displaystyle 3^3 = 23 + 2^2 \qquad \Rightarrow 27 =  27$
# $\displaystyle 5^3 = 25 + 10^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 3^3 = 26 + 1^2 \qquad \Rightarrow 27 =  27$
# $\displaystyle 4^3 = 28 + 6^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 8^3 = 28 + 22^2 \qquad \Rightarrow 512 =  512$
# $\displaystyle 11^3 = 35 + 36^2 \qquad \Rightarrow 1331 =  1331$
# $\displaystyle 4^3 = 39 + 5^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 10^3 = 39 + 31^2 \qquad \Rightarrow 1000 =  1000$
# $\displaystyle 14^3 = 40 + 52^2 \qquad \Rightarrow 2744 =  2744$
# $\displaystyle 5^3 = 44 + 9^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 21^3 = 45 + 96^2 \qquad \Rightarrow 9261 =  9261$
# $\displaystyle 6^3 = 47 + 13^2 \qquad \Rightarrow 216 =  216$
# $\displaystyle 12^3 = 47 + 41^2 \qquad \Rightarrow 1728 =  1728$
# $\displaystyle 4^3 = 48 + 4^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 9^3 = 53 + 26^2 \qquad \Rightarrow 729 =  729$
# $\displaystyle 7^3 = 54 + 17^2 \qquad \Rightarrow 343 =  343$
# $\displaystyle 4^3 = 55 + 3^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 18^3 = 56 + 76^2 \qquad \Rightarrow 5832 =  5832$
# $\displaystyle 4^3 = 60 + 2^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 5^3 = 61 + 8^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 4^3 = 63 + 1^2 \qquad \Rightarrow 64 =  64$
# $\displaystyle 8^3 = 71 + 21^2 \qquad \Rightarrow 512 =  512$
# $\displaystyle 6^3 = 72 + 12^2 \qquad \Rightarrow 216 =  216$
# $\displaystyle 5^3 = 76 + 7^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 20^3 = 79 + 89^2 \qquad \Rightarrow 8000 =  8000$
# $\displaystyle 13^3 = 81 + 46^2 \qquad \Rightarrow 2197 =  2197$
# $\displaystyle 7^3 = 87 + 16^2 \qquad \Rightarrow 343 =  343$
# $\displaystyle 5^3 = 89 + 6^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 6^3 = 95 + 11^2 \qquad \Rightarrow 216 =  216$
# $\displaystyle 5^3 = 100 + 5^2 \qquad \Rightarrow 125 =  125$
# $\displaystyle 10^3 = 100 + 30^2 \qquad \Rightarrow 1000 =  1000$

# %% [markdown]
# Compute and plot the following two sequences:
#
# $\huge
# s_1 = \frac{-1^a}{\ln(\frac{1}{e^a})}\\
# \huge
# s_2 = \frac{\sqrt{a}}{\left(\frac{-\pi}{2}\right)^a}$
#
# for $a \in \mathbb{Z}$

# %%
#a = 0 ; denom=0 in s1; 
# a>=0; sqrt in s2 >0 
a = np.arange(1,100)

s1 = np.zeros(len(a))
s2 = np.zeros(len(a))

for a_idx, a in enumerate(a):
    s1[a_idx] = ((-1)**a) / (np.log(1/np.exp(a)))
    s2[a_idx] = np.sqrt(a) / ((-np.pi/2)**a)


fig, ax = plt.subplots(1, 2,figsize=(10,4))
ax[0].plot(s1)
ax[0].set_title('Sequence $s_1$')

ax[1].plot(s2)
ax[1].set_title('Sequence $s_2$')

plt.show()
