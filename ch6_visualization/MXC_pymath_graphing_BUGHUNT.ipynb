# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %% [markdown]
# # Graphing bug hunt!

# %%
plt.plot(3,2,'ro')

# set axis limits
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.show()

# %%
# plot a line
plt.plot([0,3],[0,5])
plt.show()

# %%
# x = range(-3,4)
# y = np.zeros(len(x))
# Y = [[el, 2-el**2] for el in x]
# display(Math(sym.latex(sym.sympify(Y))))


# for i in x:
#     y[i,1] = 2 - x**2

x = np.linspace(-3,4, 100)
y = 2-x**2
plt.plot(x,y,'-')
plt.show()

# %%
# plot two lines
plt.plot([-2,3],[4,0],'b', label='line 1')
plt.plot([0,3],[-3,3],'r', label='line 2')

plt.legend()
plt.show()

# %%
randmat = np.random.randn(5,9)
# print(randmat)

# draw a line from lower-left corner to upper-right corner
plt.plot(
    [0,8],
    [4,0],
    color=(.4,.1,.9),
    linewidth=5)

plt.imshow(randmat)
plt.set_cmap('Purples')
plt.show()

# %%
# plot two lines
plt.plot([-2,3],[4,0],'b', label='line')
plt.plot([0,3],[-3,3],'r', label='line2d')
axis = plt.gca()

plt.legend = True
plt.show()

# %%
x = np.linspace(1,4,20)
y = x**2/(x-2)

plt.plot(x,y)

# adjust the x-axis limits according to the first and last points in x
axis = plt.gca()
plt.xlim(axis.get_xlim()[0], axis.get_xlim()[1])

plt.show()

# %%
x = sym.symbols('x')
y = x**2 - 3*x

xrange = range(-10,11)

for i in xrange:
    plt.plot(i,y.subs({x: i}),'o')
        
plt.xlabel('x')
plt.ylabel('$f(x) = %s$' %sym.latex(y))
plt.show()

# %%
x = np.linspace(-5,5,100)
m = 2
b = 1

y = m*x+b

plt.plot(x,y)
plt.show()

# %%
x = range(-20,21)

for idx, i in enumerate(x):
    c = idx/len(x)
    plt.plot(
        [0, i],
        [0, abs(i)**0.5],
        color=(c,c,c)
    
    )
    
plt.axis('off')
plt.show()

# %%
# draw a checkerboard with purple numbers on top

m = 8
n = 10

# initialize matrix
C = np.zeros((m,n))

# populate the matrix
for i in range(0,m):
    for j in range(0,n):
        C[i,j] = (-1)**(i+j)
        

# display some numbers
for i in range(0,m):
    for j in range(0,n):
        plt.text(
            j,
            i,
            i+j,
            horizontalalignment='center',
            verticalalignment='center',
            fontdict=dict(color='m')
        )


plt.imshow(C)
plt.set_cmap('gray')
plt.show()
