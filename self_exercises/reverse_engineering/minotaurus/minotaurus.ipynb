# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
angles = np.linspace(0, 2*np.pi, 100)



for i in np.arange(100, 200):
    x = np.cos(angles)*i**(1/5)-i**(1/5)
    y = np.sin(angles)*i**(1/5)

    plt.plot(x, y, '-k', linewidth=1)

for i in np.arange(40, 100, 10):
    x = np.cos(angles)*i**(1/5)-i**(1/5)
    y = np.sin(angles)*i**(1/5)

    plt.plot(x, y, '-k', linewidth=1)

# for i in np.arange(10, 20):
#     x = np.cos(angles)*i**(1/10)-i
#     y = np.sin(angles)*i**(1/10)

#     plt.plot(x, y, '-k', linewidth=1)
# x = np.cos(angles)-1
# y = np.sin(angles)
# plt.plot(x, y, '-k', linewidth=1)

plt.axis('square')
# plt.gca().set_aspect('equal')
plt.gcf().set_size_inches(8.3, 5.8) # A5 in inches
plt.show()

# %%
n=300
angles = np.linspace(0, 2*np.pi, n)
r_big = 120
r_main = 100
delta_r = .1

# drawin the main  circle (white)
x = np.cos(angles)*60
y = np.sin(angles)*60
plt.plot(x, y, '-k', linewidth=1)

for i in np.arange(50, 42, -.1):
    x = np.cos(angles)*i
    y = np.sin(angles)*i + i - 55
    plt.plot(x, y, '-k', linewidth=1, alpha=1)

# drawin the second circle with biggest action, r=80
x = np.cos(angles)*50
y = np.sin(angles)*50 - 5
plt.plot(x, y, '-k', linewidth=1)


# drawin the second circle with biggest action, r=80
x = np.cos(angles)*42
y = np.sin(angles)*42 - 13
plt.plot(x, y, '-k', linewidth=1)

# x_sm = np.cos(angles)*20
# y_sm = np.sin(angles)*20 + 20 - 55
# plt.plot(x, y, '--b', linewidth=2, alpha=.8)

# drawin the second circle with biggest action, r=80
x_sm = np.cos(angles)*30
y_sm = np.sin(angles)*30+30-55
plt.plot(x, y, 'k', linewidth=2)

for k in np.arange(42, 30, -2):
    x = np.cos(angles)*k
    y = np.sin(angles)*k + k - 55
    plt.plot(x, y, '-k', linewidth=1, alpha=1)


    for m in range(n):
        plt.plot([x_sm[m], x[m]], [y_sm[m], y[m]], '-k', linewidth=.5, alpha=1)


# last big
x = np.cos(angles)*30
y = np.sin(angles)*30+30-55
plt.plot(x, y, '-k', linewidth=1)

# last big
x = np.cos(angles)*22-3
y = np.sin(angles)*22-17.5
plt.plot(x, y, '-k', linewidth=1)

for _ in range(5):
    plt.text(-7, -58, 'ESCARGOT', fontsize=8)
plt.axis('square')
plt.axis('off')
plt.grid()
plt.gcf().set_size_inches(12, 8) # A5 in inches
plt.show()

# %%
40/44
# Out:
# 0.9090909090909091
