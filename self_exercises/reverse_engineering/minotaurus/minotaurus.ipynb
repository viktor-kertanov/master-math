# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
angles = np.linspace(0, 2*np.pi, 100)



for i in np.arange(100, 200):
    x = np.cos(angles)*i**(1/5)-i**(1/5)
    y = np.sin(angles)*i**(1/5)

    plt.plot(x, y, '-k', linewidth=1)

for i in np.arange(40, 100, 10):
    x = np.cos(angles)*i**(1/5)-i**(1/5)
    y = np.sin(angles)*i**(1/5)

    plt.plot(x, y, '-k', linewidth=1)

# for i in np.arange(10, 20):
#     x = np.cos(angles)*i**(1/10)-i
#     y = np.sin(angles)*i**(1/10)

#     plt.plot(x, y, '-k', linewidth=1)
# x = np.cos(angles)-1
# y = np.sin(angles)
# plt.plot(x, y, '-k', linewidth=1)

plt.axis('square')
# plt.gca().set_aspect('equal')
plt.gcf().set_size_inches(8.3, 5.8) # A5 in inches
plt.show()

# %%
n=150
angles = np.linspace(0, 2*np.pi, n)
r_big = 120
r_main = 100
delta_r = .1

# drawin the main  circle (white)

x = np.cos(angles)*60
y = np.sin(angles)*60
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

for i in np.arange(50, 42, -.1):
    x = np.cos(angles)*i
    y = np.sin(angles)*i + i - 55
    for _ in range(4, 8):
        plt.plot(x, y, '-k', linewidth=1, alpha=1)

# drawin the second circle with biggest action, r=80
x = np.cos(angles)*50
y = np.sin(angles)*50 - 5
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)


# drawin the second circle with biggest action, r=80
x = np.cos(angles)*42
y = np.sin(angles)*42 - 13
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

# drawin the second circle with biggest action, r=80
x_sm = np.cos(angles)*30
y_sm = np.sin(angles)*30+30-55
for _ in range(4, 8):
    plt.plot(x, y, 'k', linewidth=2)

for k in np.arange(42, 30, -2):
    x = np.cos(angles)*k
    y = np.sin(angles)*k + k - 55
    for _ in range(4, 8):
        plt.plot(x, y, '-k', linewidth=1, alpha=1)


    for m in range(n):
        for _ in range(2, 5):
            plt.plot([x_sm[m], x[m]], [y_sm[m], y[m]], '-k', linewidth=1, alpha=1)


# last big
x = np.cos(angles)*30
y = np.sin(angles)*30+30-55
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)



dx = 3
# smaller
x = np.cos(angles)*22-dx
y = np.sin(angles)*22-17.5
for _ in range(2, 5):
    plt.plot(x, y, '-k', linewidth=1)

for i in np.arange(22, 19, -.1):
    x = np.cos(angles)*i-dx
    y = np.sin(angles)*i + i - 55 + 15.5
    for _ in range(2, 3):
        plt.plot(x, y, '-k', linewidth=1, alpha=.5)




# smaller
x = np.cos(angles)*19-dx
y = np.sin(angles)*19-17.5-3
for _ in range(2, 5):
    plt.plot(x, y, '-k', linewidth=1)


# smaller
x_sm = np.cos(angles)*17-dx
y_sm = np.sin(angles)*17-17.5-3-1.2
for _ in range(2, 5):
    plt.plot(x_sm, y_sm, '-k', linewidth=1)

# smaller radians
for m in range(n):
        for _ in range(2, 3):
            plt.plot([x_sm[m], x[m]], [y_sm[m], y[m]], '-k', linewidth=1, alpha=1)


# smaller
x = np.cos(angles)*14-dx+2.1
y = np.sin(angles)*14-17.5-5
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

# smaller
x = np.cos(angles)*11-dx+3
y = np.sin(angles)*11-17.5-7
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

dx_2 = 2
# smaller
x = np.cos(angles)*8-dx+3
y = np.sin(angles)*8-17.5-8

for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

# smaller
x = np.cos(angles)*6-dx+2
y = np.sin(angles)*6-17.5-8

for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)

# smaller
x = np.cos(angles)*4-dx+1
y = np.sin(angles)*4-17.5-8.5
for _ in range(4, 8):
    plt.plot(x, y, '-k', linewidth=1)


# ESCARGOT TEXT
for _ in range(5):
    plt.text(-9, -58.5, 'ESCARGOT', fontsize=6)
plt.axis('square')
plt.axis('off')
plt.grid()
plt.gcf().set_size_inches(7, 5) # A5 in inches
plt.savefig('escargot.svg')
plt.show()

# %%
40/44
# Out:
# 0.9090909090909091
