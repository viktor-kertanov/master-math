# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean_x = 0
sigma = np.pi
n = 30
random_nums = np.random.randn(n)*sigma
random_nums -= np.mean(random_nums)

circle_y = np.sin(random_nums)

y = np.zeros(n)

plt.plot(random_nums, y, '.k')
plt.plot(random_nums, circle_y, '.k')

# plt.gca().set_aspect('equal')
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 30
angles = np.random.randn(n)*sigma + mean
# angles = np.random.exponential(scale=1, size=n) + mean
# angles = angles[(angles > 0) & (angles < np.pi/2)]

# angles = np.linspace(0, np.pi/2, 100)
# x = np.abs(0 - np.cos(angles))
x = np.cos(0-angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param = np.random.rand()*0.02
    plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )
    plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )

plt.gca().set_aspect('equal')
plt.axis('square')
plt.gcf().set_size_inches(8, 8)
plt.show()

# %%
rows = 3
cols_in_row=5
fig, ax = plt.subplots(rows, cols_in_row, figsize=(15, 15))
fig.tight_layout()
row_idx, col_idx = np.indices((rows, cols_in_row))

mean = np.pi/4
sigma = np.pi

for idx in np.arange(rows*cols_in_row):
    n = np.random.randint(40, 120)
    angles = np.random.randn(n)*sigma + mean
    # angles = np.random.exponential(scale=1, size=n) + mean
    angles = angles[(angles > 0) & (angles < np.pi/2)]

    # angles = np.linspace(0, np.pi/2, 100)
    # x = np.abs(0 - np.cos(angles))
    x = np.cos(0-angles)
    y = np.sin(angles)

    coords = zip(x, y)
    r = 1

    cur_plt = ax[row_idx.ravel()[idx], col_idx.ravel()[idx]]
    for coord in coords:
        random_param = np.random.rand()*0.02
        cur_plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )
        cur_plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )

    cur_plt.axis('square')
    cur_plt.axis([-r, r, -r, r])
    cur_plt.axis('off')

plt.gcf().set_size_inches(7, 5)
plt.subplots_adjust(wspace=0.1, hspace=0.2)
plt.savefig('circles_distro.svg', dpi=100)
plt.show()

# %%
# как сделать так, чтобы каждая линия была осью, вокруг которой кружится синус или косинус волна
# как сделать так, чтобы экспоненциальное распределение было нормализовано вокруг тех параметров, которые нам нужны - чтобы икс тяготел к 1 и был редок у нуля
mean = np.pi/4
sigma = np.pi
n = 30
angles = np.random.exponential(scale=1, size=n)/(np.pi/1.5)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )
    plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(8, 8)
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 30
# angles = np.random.exponential(scale=2, size=n)/(np.pi/1.5)
angles = np.linspace(0, np.pi/2, 10)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 6
for idx, coord in enumerate(coords):
    random_param=0
    dots_x = np.linspace(-coord[0]*r, coord[0]*r, 10000)
    dots_y = np.sin(5*r*dots_x)/5 + coord[1]*r
    plt.plot(dots_x, dots_y, 'k-', linewidth=1)
    plt.plot(dots_x, -dots_y, 'k-', linewidth=1)
    plt.plot([-coord[0]*r, coord[0]*r], [coord[1]*(r-random_param), coord[1]*(r-random_param)], '-b', linewidth=1 )
    plt.plot([-coord[0]*r, coord[0]*r], [-coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-b', linewidth=1 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(8, 8)
# plt.savefig('funny_error_6.svg', dpi=100)
plt.show()

# %%
n=1000
rand = np.random.exponential(scale=1, size=n)/(np.pi)

max_rand = np.pi/2
rand_filtered = rand[rand<max_rand]

plt.plot(rand, '.k', alpha=.1)
plt.plot(rand_filtered, '.r')
print(f"Mean is :{np.mean(rand)}. Pi/4: {np.round(np.pi/4, 2)}")
plt.plot([0, n], [np.mean(rand), np.mean(rand)], 'r--', linewidth=.5)
plt.plot([0, n], [max_rand, max_rand], 'g--', linewidth=1)


plt.show()
# Out:
# Mean is :0.33175251449330556. Pi/4: 0.79

# %%
mean = np.pi/4
sigma = np.pi
n = 15
angles = np.random.exponential(scale=1, size=n)/(np.pi/1.5)
angles = np.arange(100)
delta = np.pi/(7*n)
angles = angles*delta
angles = angles[(angles > 0) & (angles < np.pi/2.07)]
# print(angles)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    for _ in range(np.random.randint(1, 4)):
        plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )
        plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 5)
plt.savefig('test_axi_circle.svg', dpi=100)
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 500
angles = np.logspace(np.log10(.001), np.log10(np.pi/2), n)[:-5]
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )
    plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
n = 15
max_val = np.pi / 2
angles = 2**np.arange(n+1) * (max_val / 2**n)

x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )
    plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
n = 5
max_val = 8
my_row = np.arange(n+1)
twos = 2**my_row
print(twos)

normalized_coeffs = twos*max_val/2**n
print(normalized_coeffs)

n = 5
max_val = 8
my_row = np.arange(n+1)
twos = 2*my_row
print(twos)
# Out:
# [ 1  2  4  8 16 32]
# [0.25 0.5  1.   2.   4.   8.  ]
# [ 0  2  4  6  8 10]

# %%
mean = np.pi/4
sigma = np.pi
n = 150
angles = np.logspace(np.log10(.001), np.log10(np.pi/2), n)[:-5]
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([-coord[0], coord[0]], [coord[1]*(r-random_param), coord[1]*(r-random_param)], '-k', linewidth=.5 )
    plt.plot([-coord[0], coord[0]], [-coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=.5 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 40
angles = np.logspace(np.log10(.001), np.log10(np.pi/2), n)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([-coord[0], coord[0]], [-coord[1]*(r-random_param), coord[1]*(r-random_param)], '-k', linewidth=.5 )
    plt.plot([coord[0], -coord[0]], [-coord[1]*(r-random_param), coord[1]*(r-random_param)], '-k', linewidth=.5 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
n = 100
r=1
ax_lim = r*1.1
angles = np.linspace(0, 2*np.pi, n)
x = np.cos(angles)
y = np.sin(angles)

plt.plot(x, np.zeros(n), 'k.', markersize=1)
plt.plot(np.zeros(n), y, 'k.', markersize=1)

for i in np.arange(1, n):
    # print(f"X[i]: {x[i]}. Y[i]: {y[i]}")
    plt.plot([x[i], x[i-1]], [y[i], y[i-1]], linewidth=.5)
    plt.plot([x[i], x[i-1]], [y[i-1], y[i]], linewidth=.5)

plt.axis('square')
plt.axis([-ax_lim, ax_lim, -ax_lim, ax_lim])
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 15
angles = np.linspace(0, np.pi/2)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    plt.plot([coord[0], coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], linewidth=.5 )
    plt.plot([-coord[0], coord[0]], [coord[1]*(r-random_param), coord[1]*(r-random_param)], linewidth=.5)
    plt.plot([-coord[0], coord[0]], [-coord[1]*(r-random_param), -coord[1]*(r-random_param)], linewidth=.5 )
    plt.plot([-coord[0], -coord[0]], [coord[1]*(r-random_param), -coord[1]*(r-random_param)], linewidth=.5)

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
mean = np.pi/4
sigma = np.pi
n = 15
angles = np.random.exponential(scale=1, size=n)/(np.pi/1.5)
angles = np.arange(100)
delta = np.pi/(7*n)
angles = angles*delta
angles = angles[(angles > 0.05) & (angles < np.pi/2)]
# print(angles)
x = np.cos(angles)
y = np.sin(angles)

coords = zip(x, y)
r = 1
for coord in coords:
    random_param=0
    for _ in range(np.random.randint(1, 4)):
        plt.plot([-coord[0], coord[0]], [coord[1]*(r-random_param), coord[1]*(r-random_param)], '-k', linewidth=1 )
        plt.plot([coord[0], -coord[0]], [-coord[1]*(r-random_param), -coord[1]*(r-random_param)], '-k', linewidth=1 )

plt.axis([-r, r, -r, r])
plt.axis('square')
plt.axis('off')
plt.gcf().set_size_inches(7, 5)
plt.savefig('test_axi_circle.svg', dpi=100)
plt.show()
